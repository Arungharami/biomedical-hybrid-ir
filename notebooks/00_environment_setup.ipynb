# %% [markdown]
# # 00 — Environment Setup
#
# CAP 6776 Information Retrieval — Hybrid Biomedical IR project.
#
# Installs dependencies (on Colab), detects the available accelerator (CUDA / Apple MPS / CPU), and prints the exact library versions this run will use — the same versions `manifests.py` records into every experiment's manifest, so this notebook's output is directly comparable to `results/manifests/*.json`.

# %%
# If running on Colab, clone the repo and install deps. Skipped automatically
# when already inside a local checkout (REPO_ROOT / 'src' already importable).
import os, sys, subprocess

IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    if not os.path.exists('biomedical-hybrid-ir'):
        subprocess.run(['git', 'clone', 'https://github.com/Arungharami/biomedical-hybrid-ir'], check=True)
    os.chdir('biomedical-hybrid-ir')
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-r', 'requirements.txt'], check=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-e', '.'], check=True)

sys.path.insert(0, os.path.join(os.getcwd(), 'src'))
print('cwd:', os.getcwd())

# %%
from biomedical_ir.utils import detect_device, library_versions, set_seed

set_seed(42)
device = detect_device('auto')
print('Selected device:', device)
print()
for pkg, version in library_versions().items():
    print(f'{pkg:25s} {version}')

# %% [markdown]
# If `device` above is `cpu` on Colab, check **Runtime → Change runtime type → GPU** and re-run this cell.

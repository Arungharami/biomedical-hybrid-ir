# %% [markdown]
# # 11 — Export Research Results for the Web Portal (M11)
#
# Runs `scripts/export_web_results.py` if it exists (built as part of M11, the Next.js research portal) — generates the compact JSON artifacts under `web/data/` that the portal reads (Section 36 of the project spec). The portal never runs transformer models itself; it only reads these exported, verified files (see `docs/architecture.md`).

# %%
# If running on Colab, clone the repo and install deps. Skipped automatically
# when already inside a local checkout (REPO_ROOT / 'src' already importable).
import os, sys, subprocess

IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    if not os.path.exists('biomedical-hybrid-ir'):
        subprocess.run(['git', 'clone', 'https://github.com/Arungharami/biomedical-hybrid-ir'], check=True)
    os.chdir('biomedical-hybrid-ir')
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-r', 'requirements.txt'], check=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-e', '.'], check=True)

sys.path.insert(0, os.path.join(os.getcwd(), 'src'))
print('cwd:', os.getcwd())

# %%
import os

script = 'scripts/export_web_results.py'
if os.path.exists(script):
    result = subprocess.run([sys.executable, script], cwd=os.getcwd())
    assert result.returncode == 0, 'Script failed -- see output above.'
else:
    print(f'{script} not found yet -- this lands with M11 (the Next.js research portal).')
    print('See the README Experiment status table for current milestone progress.')
